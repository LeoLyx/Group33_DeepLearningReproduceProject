# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import nibabel as nib

# %%
os.chdir("/Users/caihongqingqiqiu/gaoxiang/result_2D/")
files="jetd.nii.gz"

# %%
test_load1=nib.load(files).get_fdata()

# %%
test_load1.shape
# Out:
# (1, 159, 191)

# %%
test=test_load1[0,:,:]
plt.imshow(test)
plt.show()

# %%
os.chdir("/Users/caihongqingqiqiu/gaoxiang/result_2D/")
files="neg_jetd.nii.gz"
test_load1=nib.load(files).get_fdata()
test_load1.shape
# Out:
# (1, 159, 191)

# %%
test=test_load1[0,:,:]
plt.imshow(test)
plt.show()

# %%
os.chdir("/Users/caihongqingqiqiu/gaoxiang/result_2D/")
files="warped.nii.gz"
test_load1=nib.load(files).get_fdata()
test_load1.shape

test=test_load1[:,:]
plt.imshow(test)
plt.show()
